# %% [markdown]
# <a href="https://colab.research.google.com/github/iamharish22/Global-Terrorism-dataset-analysis/blob/main/Numerical_Python_Capston_project_day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - (EDA) Exploratory Data Analysis of Global Terrorism Dataset
# ##### **Contribution**    - Individual
# ##### **Name**            - Harish Kumar
# ##### **Email_id**        - *harish.it.17019@recb.recb.ac.in*
# ##### **Cohort**          - Orlando

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ###**Project Title :-** Exploratory Data Analysis of Global Terrorism Dataset
# ###**Project Summary :-**
# The "Exploratory Data Analysis of Global Terrorism Dataset" is a comprehensive examination of worldwide terrorist incidents spanning several decades. This project aims to gain deeper insights into global acts of terrorism by analyzing a rich dataset that includes information on the location, time, nature of the attack, the groups responsible, and more.
#
# ###**Key Objectives :-** First of all this is a open end project and don't have a fix output so we do the anaylsis according to our thought process and try to find out some very usefull insights from the dataset
# 1.**Data Exploration :-** Conduct a detailed examination of the dataset to understand its formation, information which collect by the dataset and quality of the dataset.
#
# 2.**Summary Statistics :-** Summary the dataset in a mathematical way to find trends and patterns.
#
# 3.**Temporal Analysis:-** Investigate how terrorism has evolved over time, identifying peaks, trends, and anomalies.
#
# 4.**Geospatial Analysis:-** Explore geographical hotspots and regional variations in terrorism, along with the impact on different countries.
#
# 5.**Group Analysis:-** Examine the involvement of various terrorist groups and identify their activities and impacts.
#
# 6.**Attack Types and Targets:-** Analyze the methods and targets of terrorist attacks to uncover insights about tactics and motivations.
#
# 7.**Casualty Analysis:-** Investigate the human and economic costs of terrorism by examining casualties and economic damages.
#
# ###**Expected Outcomes:-**
#
# Through this project, we aim to provide a comprehensive understanding of global terrorism dynamics and insights that can inform future research and policy decisions. The analysis will contribute to a better grasp of the global security landscape, enabling data-driven decisions to mitigate terrorism risks.
#
# This project will be documented using Google Colab Notebooks and visualized through interactive plots and graphs, making it accessible to a wide audience interested in global security, data analysis, and public policy.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# ###*This is the GitHub link for the project*
# https://github.com/iamharish22/Global-Terrorism-dataset-analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ####**Problem Statement:-**
#
# ####Terrorism has remained a significant global concern, affecting societies and nations across the world. In this project, our aim is to conduct a comprehensive Exploratory Data Analysis (EDA) of a Global Terrorism dataset to gain insights into the patterns, trends, and characteristics of terrorist incidents worldwide. By addressing this problem, we seek to provide valuable information that can assist policymakers, security experts, and researchers in understanding and addressing the challenges posed by terrorists.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ###**These are Some business objectives In which the project can be helpful**
#
# 1.Reduction in security incidents or breaches.
#
# 2.Improved response time to security incidents.
#
# 3.Enhanced threat detection capabilities.
#
# 4.Reduction in the economic impact of terrorism-related incidents.
#
# 5.Increase in compliance with security regulations.
#
# 6.Enhanced security collaboration with international partners.
#
# These business objectives will guide the EDA project and ensure
# that the analysis is aligned with the organization's strategic goals and security priorities.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing the Libraries which are required for the data anaylsis
from IPython.display import display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import math
from google.colab import drive
from sklearn.impute import SimpleImputer
from tabulate import tabulate
import folium
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Loading The Global Terrorism Dataset Using Google Drive
# Mounting the Google Drive
drive.mount('/content/MyDrive')
# Out:
# Drive already mounted at /content/MyDrive; to attempt to forcibly remount, call drive.mount("/content/MyDrive", force_remount=True).

# %%
## Load the Csv File of the Dataset Using Pandas and make a DataFrame of the Dataset
# Handle the error, e.g., skip problematic rows, replace characters, or take other appropriate actions.
try:
    df = pd.read_csv('/content/MyDrive/MyDrive/project datasets/Global Terrorism Data.csv', encoding='latin1',low_memory=False)
except UnicodeDecodeError as e:
    print(f"Error: {e}")

# %% [markdown]
# ### Dataset First View

# %% [markdown]
# ####Complete Dataset View

# %%
# Dataset First Look
pd.set_option('display.max_columns',None)
df.head() # This is how our Dataset's Dataframe Look like
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %% [markdown]
# ####Fitering The Importanat Columns
# **There are to many columns in the dataset which are not very usefull for EDA so we Filter the dataset and find 39 important columns which are very important**

# %%
terror = df[['eventid','iyear','imonth','iday','country','country_txt','region','region_txt','provstate','city','latitude','longitude',
            'success','suicide','attacktype1','attacktype1_txt','targtype1','targtype1_txt','corp1',
          'target1','natlty1','natlty1_txt','gname','motive','individual','weaptype1','weaptype1_txt','claimed','weapdetail',
          'nkill','nwound','property','propvalue','ransom',
          'addnotes','dbsource','INT_LOG','INT_IDEO','summary']]

# %%
terror.head() ## This is how our filtered dataset looks like
# Out:
#         eventid  iyear  imonth  iday  country         country_txt  region  \
# 0  197000000001   1970       7     2       58  Dominican Republic       2
# 1  197000000002   1970       0     0      130              Mexico       1
# 2  197001000001   1970       1     0      160         Philippines       5
# 3  197001000002   1970       1     0       78              Greece       8
# 4  197001000003   1970       1     0      101               Japan       4
#
#                     region_txt provstate           city   latitude  \
# 0  Central America & Caribbean       NaN  Santo Domingo  18.456792
# 1                North America   Federal    Mexico city  19.371887
# 2               Southeast Asia    Tarlac        Unknown  15.478598
# 3               Western Europe    Attica         Athens  37.997490
# 4                    East Asia   Fukouka        Fukouka  33.580412
#
#     longitude  success  suicide  attacktype1                 attacktype1_txt  \
# ...

# %% [markdown]
# ####Renaming the columns

# %%
terror.rename(columns = {'eventid':'event_id','iyear':'year','imonth':'month','iday':'day','country':'country_code','country_txt':'country_name',
               'region':'region_code','region_txt':'region_name','provstate':'state','attacktype1':'attacktype_code','attacktype1_txt':'attacktype_name',
               'targtype1':'targettype_code','targtype1_txt':'targettype_name','corp1':'corporation',
               'target1':'target','natlty1':'nationality','natlty1_txt':'nationality_name','gname':'group_name','weaptype1':'weaptype_code','weaptype1_txt':'weapontype_name',
               'weapdetail':'weapon_details','nkill':'fatalities','nwound':'injured','property':'property_damage','propvalue':'propganda_value',
               'ransom':'ransom_demand'},inplace = True)

# %%
terror.columns
# Out:
# Index(['event_id', 'year', 'month', 'day', 'country_code', 'country_name',
#        'region_code', 'region_name', 'state', 'city', 'latitude', 'longitude',
#        'success', 'suicide', 'attacktype_code', 'attacktype_name',
#        'targettype_code', 'targettype_name', 'corporation', 'target',
#        'nationality', 'nationality_name', 'group_name', 'motive', 'individual',
#        'weaptype_code', 'weapontype_name', 'claimed', 'weapon_details',
#        'fatalities', 'injured', 'property_damage', 'propganda_value',
#        'ransom_demand', 'addnotes', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'summary'],
#       dtype='object')

# %% [markdown]
# #### Dataset Rows & Columns count
#
# We have filterted Dataset, Now we started working on it

# %%
# Counts Dataset's Rows & Columns
print(f"The Dataset have {terror.shape[0]} Rows and {terror.shape[1]} Columns")
# Out:
# The Dataset have 181691 Rows and 39 Columns

# %% [markdown]
# #####**ROWS** = 181691
# #####**COLUMNS** = 39

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information
print(terror.info()) ## It Gives all the inforamtion of the Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 39 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   event_id          181691 non-null  int64
#  1   year              181691 non-null  int64
#  2   month             181691 non-null  int64
#  3   day               181691 non-null  int64
#  4   country_code      181691 non-null  int64
#  5   country_name      181691 non-null  object
#  6   region_code       181691 non-null  int64
#  7   region_name       181691 non-null  object
#  8   state             181270 non-null  object
#  9   city              181257 non-null  object
#  10  latitude          177135 non-null  float64
#  11  longitude         177134 non-null  float64
#  12  success           181691 non-null  int64
#  13  suicide           181691 non-null  int64
#  14  attacktype_code   181691 non-null  int64
#  15  attacktype_name   181691 non-null  object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicates_counts = terror.duplicated().sum()
print(f'The Dataset Have {duplicates_counts} Duplicates')
# Out:
# The Dataset Have 0 Duplicates

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Counting the missing Null values
print(f"The Dataset Have Total {terror.isnull().sum().sum()} NUll / Missing Values")
# Out:
# The Dataset Have Total 814359 NUll / Missing Values

# %%
# Visualizing the missing values
fig = plt.figure(figsize = (20,15))
sns.heatmap(terror.isnull()) ## Using this we can see that Where is the Null values its shows them at the graph for the Quick Anaylsis
plt.title("HeatMap For Showing The NULL Values in the Dataset")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ####**Information About The Dataset** :-
# ####***1.ROWS and COLUMNS Information:-***
# **NUMBER OF ROWS :-** 181691 (indexing 0 to 181691)
#
# **NUMBER OF COLUMNS:-** 39
# ####***2.Datatypes of columns:-***
# Integer Type :- 15
#
# Float Types :- 8
#
# Object Types :-16
#
# ####***3.Dataset Have 0 Duplicate Values***
#
# ####***4.Dataset Have  814359 Missing/Null Values***

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# ###Columns and Description

# %%
# Dataset Columns
# List of columns Are here
(list(terror.columns))
# Out:
# ['event_id',
#  'year',
#  'month',
#  'day',
#  'country_code',
#  'country_name',
#  'region_code',
#  'region_name',
#  'state',
#  'city',
#  'latitude',
#  'longitude',
#  'success',
#  'suicide',
#  'attacktype_code',
#  'attacktype_name',
#  'targettype_code',
#  'targettype_name',
#  'corporation',
#  'target',
#  'nationality',
#  'nationality_name',
#  'group_name',
#  'motive',
#  'individual',
#  'weaptype_code',
#  'weapontype_name',
#  'claimed',
#  'weapon_details',
#  'fatalities',
#  'injured',
#  'property_damage',
#  'propganda_value',
#  'ransom_demand',
#  'addnotes',
#  'dbsource',
#  'INT_LOG',
#  'INT_IDEO',
#  'summary']

# %%
# Dataset Describe
# Here we use describe menthod of the pandas to know the description of the dataset
terror.describe()
# Out:
#            event_id           year          month            day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#         country_code    region_code       latitude     longitude  \
# count  181691.000000  181691.000000  177135.000000  1.771340e+05
# mean      131.968501       7.160938      23.498343 -4.586957e+02
# std       112.414535       2.933408      18.569242  2.047790e+05
# min         4.000000       1.000000     -53.154613 -8.618590e+07
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **1.Event ID:** A unique identifier for each terrorist event or incident.
#
# **2.Year:** The year in which the terrorist event occurred.
#
# **3.Month:** The month in which the terrorist event occurred.
#
# **4.Day:** The day of the month on which the terrorist event occurred.
#
# **5.Country Code:** Unique (ISD) Code of the Country
#
# **6.Country Name:** The Name country in which the terrorist event took place.
#
# **7.Region Code:** code of The region or subregion within the country where the event occurred.
#
# **8.Region Name:** Name of the region or subregion within the country where the event occurred.
#
# **9.State:** State of the countrty in which the attack occured
#
# **10.City:** The city or specific location where the terrorist event occurred.
#
# **11.Latitude:** The geographic latitude coordinate of the event's location.
#
# **12.Longitude:** The geographic longitude coordinate of the event's location.
#
# **13.Summary:** The Summary of the attack
#
# **14.Success:** The attack successful or not
#
# **15.Suicide:** Is there any sucide happened in the acttack
#
# **16.Attack Type Code:** Code of The method or type of attack used in the event (e.g., bombing, armed assault, assassination).
#
# **17.Attacktype Name:** Name of The method or type of attack used in the event (e.g., bombing, armed assault, assassination)
#
# **18.Targettype Code:** Code of the type of target or victim (e.g., civilians, military, police, government, businesses).
#
# **19.Targetype Name:** The type of target or victim (e.g., civilians, military, police, government, businesses).
#
# **20.Corporation:** The corporation which is targeted
#
# **21.Target:** Specific Target on which the attack happened
#
# **22.Nationality:** Code of Nationality of the target
#
# **23.Nationality Name:** Name of the nation of the target
#
# **24.Group Name:** Name of the terrorist Group
#
# **24.Motive:** Motive of the attack
#
# **25.Individual:** Is the attack happened in a group or solo
#
# **26.Weapon Code:** Code of the weapon used in the attack
#
# **27.Weapon Name** Name of the weapon used in the attack
#
# **28.Claimed:** Is attack claimed by any terrorist group or not
#
# **29.Weapon_details:** briefly details of the weapon used in the attack
#
# **30.Fatalities:** Number of people killed in the attack
#
# **31.Injurd:** Number of people wounded in the attack
#
# **32.Propery damage:** Is any property damaged in the attack or not?
#
# **33.Propganda value:** Values of the Propaganda behind the attack
#
# **34.Ransom Demand:** Demand of the ransom or not
#
# **35.Add notes:** Extra reading material of the attack
#
# **36.db source:** Database source
#
# **37.Int Log:** Is any international connection or not
#
# **38.Int Ideo:** Is any international ideology or not behind the attack
#
# **39.Summary:** End Summary of the attack

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# We implement the Emputation the dataset to clean the data

# %%
## Handling missing /null values
## We do this opration column wise according to demand

# %%
# for month column there are 20 zero values which are not valid so Fill na
terror['month'].replace(0,np.nan,inplace = True)

# %%
# for day column
terror["day"].replace(0,np.nan,inplace = True)

# %%
# for state column
terror['state'].replace('unknown',np.nan,inplace= True)

# %%
# for city column
terror['city'].replace('Unknown',np.nan,inplace = True)

# %%
# for attacktype_name column
terror['attacktype_name'].replace('Unknown',"Other",inplace = True)

# %%
# for targettype name column
terror['targettype_name'].replace('Unknown','Other',inplace = True)

# %%
## Weapon type name
## Which rows are unkown change them to other
terror['weapontype_name'].replace('Unknown','Other',inplace = True)

# %%
# for the column corporation
# filling all the not applicable rows with Other and and Unknown with other
terror['corporation'].replace({'Unknown':'Others','Not Applicable':'Others'},inplace = True)

# %%
## There is lots of rows where -9 in the row so replace -9 with NaN
terror.replace(-9,np.nan,inplace = True)

# %%
## Drop some rows from the following columns which have NaN values
columns_where_NaN_rows_drop = ['month','day','state','city','latitude','longitude','target','nationality','nationality_name','fatalities','injured']
terror.dropna(subset = columns_where_NaN_rows_drop,inplace = True)

# %%
## Now Empute the desired values in the rest of the columns

# %%
## For corporation column
terror['corporation'].fillna('Others',inplace = True)

# %%
# For the motive column
terror['motive'].fillna('The specific motive for the attack is unknown.',inplace = True)

# %%
# For the claimed column
terror['claimed'].fillna(0.0,inplace = True)

# %%
# For weapon details column
imputer = SimpleImputer(strategy='most_frequent')
terror['weapon_details'] = imputer.fit_transform(terror[['weapon_details']])

# %%
# for property damage column
terror['property_damage'].fillna(0.0,inplace = True)

# %%
# for ransome demand column
terror['ransom_demand'].fillna(0.0,inplace =True)

# %%
#for addnotes column
imputer = SimpleImputer(strategy='most_frequent')
terror['addnotes'] = imputer.fit_transform(terror[['addnotes']])

# %%
# For INT_LOG column
terror["INT_LOG"].fillna(0.0,inplace = True)

# %%
# For INT_IDEO
terror["INT_IDEO"].fillna(0.0,inplace = True)

# %%
# Fill Not Available In summary where values in NaN
terror['summary'].fillna('Not Available',inplace = True)

# %%
## Remove all the duplicates from the data
terror.drop_duplicates(inplace = True)

# %%
# For Total casualties
# Add fatalities and injured columns
terror['total_casualties'] = terror['fatalities']+terror['injured']

# %%
# Change Value 1 and 0 with Yes Or No
# 0 ---> No
# 1 ---> Yes
terror['success'][terror['success']==1] = 'Yes'
terror['success'][terror['success']==0] = 'No'

# %%
# Change Value 1 and 0 with Yes Or No
# 0 ---> No
# 1 ---> Yes
terror['suicide'][terror['suicide']==1] = 'Yes'
terror['suicide'][terror['suicide']==0] = 'No'

# %%
# Change Value 1 and 0 with Yes Or No
# 0 ---> No
# 1 ---> Yes
terror['property_damage'][terror['property_damage']==1] = 'Yes'
terror['property_damage'][terror['property_damage']==0] = 'No'

# %%
# Change Value 1 and 0 with Yes Or No
# 0 ---> No
# 1 ---> Yes
terror['ransom_demand'][terror['ransom_demand']==1] = 'Yes'
terror['ransom_demand'][terror['ransom_demand']==0] = 'No'

# %%
# Change Value 1 and 0 with Yes Or No
# 0 ---> No
# 1 ---> Yes
terror['claimed'][terror['claimed']==1] = 'Yes'
terror['claimed'][terror['claimed']==0] = 'No'

# %%
# Change Value 1 and 0 with Yes Or No
# 0 ---> No
# 1 ---> Yes
terror['INT_LOG'][terror['INT_LOG']==1] = 'Yes'
terror['INT_LOG'][terror['INT_LOG']==0] = 'No'

# %%
# Change Value 1 and 0 with Yes Or No
# 0 ---> No
# 1 ---> Yes
terror['INT_IDEO'][terror['INT_IDEO']==1] = 'Yes'
terror['INT_IDEO'][terror['INT_IDEO']==0] = 'No'

# %%
terror.columns
# Out:
# Index(['event_id', 'year', 'month', 'day', 'country_code', 'country_name',
#        'region_code', 'region_name', 'state', 'city', 'latitude', 'longitude',
#        'success', 'suicide', 'attacktype_code', 'attacktype_name',
#        'targettype_code', 'targettype_name', 'corporation', 'target',
#        'nationality', 'nationality_name', 'group_name', 'motive', 'individual',
#        'weaptype_code', 'weapontype_name', 'claimed', 'weapon_details',
#        'fatalities', 'injured', 'property_damage', 'propganda_value',
#        'ransom_demand', 'addnotes', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'summary', 'total_casualties'],
#       dtype='object')

# %%
## Change some columns datatypes
terror[['month','day','fatalities','injured','total_casualties']] = terror[['month','day','fatalities','injured','total_casualties']].astype(int)

# %% [markdown]
# #### **This is our final Dataframe for the Analysis**
# #####**terror**

# %%
# Counting Rows and Columns from the dataset
print(f"final dataframe has {terror.shape[0]} rows and {terror.shape[1]} columns")
# Out:
# final dataframe has 151184 rows and 40 columns

# %%
# Counting NULL values in the final dataframe
terror.isnull().sum() ## There is no NULL values in the entire dataframe
# Out:
# event_id                 0
# year                     0
# month                    0
# day                      0
# country_code             0
# country_name             0
# region_code              0
# region_name              0
# state                    0
# city                     0
# latitude                 0
# longitude                0
# success                  0
# suicide                  0
# attacktype_code          0
# attacktype_name          0
# targettype_code          0
# targettype_name          0
# corporation              0
# target                   0
# nationality              0
# nationality_name         0
# group_name               0
# motive                   0
# individual               0
# weaptype_code            0
# weapontype_name          0
# claimed                  0
# weapon_details           0
# fatalities               0
# injured                  0
# property_damage          0
# propganda_value     117872
# ransom_demand            0
# ...

# %%
## Top 10 Rows of the dataset
terror.head(10)
# Out:
#         event_id  year  month  day  country_code   country_name  region_code  \
# 5   197001010002  1970      1    1           217  United States            1
# 6   197001020001  1970      1    2           218        Uruguay            3
# 7   197001020002  1970      1    2           217  United States            1
# 8   197001020003  1970      1    2           217  United States            1
# 9   197001030001  1970      1    3           217  United States            1
# 10  197001050001  1970      1    1           217  United States            1
# 11  197001060001  1970      1    6           217  United States            1
# 12  197001080001  1970      1    8            98          Italy            8
# 13  197001090001  1970      1    9           217  United States            1
# 14  197001090002  1970      1    9           217  United States            1
#
#        region_name        state         city   latitude   longitude success  \
# ...

# %%
## Check unique columns name
terror.columns.unique()
# Out:
# Index(['event_id', 'year', 'month', 'day', 'country_code', 'country_name',
#        'region_code', 'region_name', 'state', 'city', 'latitude', 'longitude',
#        'success', 'suicide', 'attacktype_code', 'attacktype_name',
#        'targettype_code', 'targettype_name', 'corporation', 'target',
#        'nationality', 'nationality_name', 'group_name', 'motive', 'individual',
#        'weaptype_code', 'weapontype_name', 'claimed', 'weapon_details',
#        'fatalities', 'injured', 'property_damage', 'propganda_value',
#        'ransom_demand', 'addnotes', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'summary', 'total_casualties'],
#       dtype='object')

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
## Unique Values of some columns
# For countries
print(f"Total Countries in the dataset is {terror['country_name'].nunique()}")
print(f"list of the all countries is {terror['country_name'].unique()}")
# Out:
# Total Countries in the dataset is 202
# list of the all countries is ['United States' 'Uruguay' 'Italy' 'Guatemala' 'Philippines' 'Venezuela'
#  'West Germany (FRG)' 'Switzerland' 'Brazil' 'Egypt' 'Dominican Republic'
#  'Argentina' 'Lebanon' 'Jordan' 'Turkey' 'Paraguay' 'East Germany (GDR)'
#  'United Kingdom' 'Greece' 'Nicaragua' 'Belgium' 'Mexico' 'Netherlands'
#  'Canada' 'Iran' 'Australia' 'Pakistan' 'Spain' 'Ethiopia' 'Sweden'
#  'South Yemen' 'Israel' 'Poland' 'Panama' 'West Bank and Gaza Strip'
#  'Ireland' 'India' 'Austria' 'France' 'South Vietnam' 'Colombia'
#  'Cambodia' 'Brunei' 'Zaire' "People's Republic of the Congo" 'Portugal'
#  'Algeria' 'El Salvador' 'Thailand' 'Haiti' 'Morocco' 'Cyprus' 'Japan'
#  'Afghanistan' 'Peru' 'Chile' 'Yugoslavia' 'Ecuador' 'New Zealand'
#  'Zambia' 'Malaysia' 'Botswana' 'Kuwait' 'Chad' 'North Yemen' 'Jamaica'
#  'Syria' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq' 'Somalia'
# ...

# %%
## For regions
print(f"Total regions in the dataset is:- {terror['region_name'].nunique()}")
print(f"List of the all regions is:-\n{terror['region_name'].unique()}")
# Out:
# Total regions in the dataset is:- 12
# List of the all regions is:-
# ['North America' 'South America' 'Western Europe'
#  'Central America & Caribbean' 'Southeast Asia'
#  'Middle East & North Africa' 'Eastern Europe' 'Australasia & Oceania'
#  'South Asia' 'Sub-Saharan Africa' 'East Asia' 'Central Asia']

# %%
## For attacktype
print(f"Total Attack types is :- {terror['attacktype_name'].nunique()}")
print(f"list of attack types is :-\n{terror['attacktype_name'].unique()}")
# Out:
# Total Attack types is :- 9
# list of attack types is :-
# ['Armed Assault' 'Assassination' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Hijacking'
#  'Hostage Taking (Kidnapping)' 'Other' 'Unarmed Assault'
#  'Hostage Taking (Barricade Incident)']

# %%
## For Group Name
print(f"Total Groups in the dataset is :-{terror['group_name'].nunique()}")
print(f"List of the total Groups is :-\n{terror['group_name'].unique()}")
# Out:
# Total Groups in the dataset is :-3193
# List of the total Groups is :-
# ['Black Nationalists' 'Tupamaros (Uruguay)' 'Unknown' ...
#  'Fatoni Warriors' 'Minorities of Metropolitan Attacks'
#  'Baloch Republican Party']

# %%
# For weapon types
print(f"Total weapon types in the dataset is :-{terror['weaptype_code'].nunique()}")
print(f"The list of the all types of weapon is :-\n{terror['weapontype_name'].unique()}")
# Out:
# Total weapon types in the dataset is :-12
# The list of the all types of weapon is :-
# ['Firearms' 'Explosives' 'Incendiary' 'Other' 'Chemical' 'Melee'
#  'Sabotage Equipment'
#  'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)'
#  'Fake Weapons' 'Radiological' 'Biological']

# %%
terror.columns
# Out:
# Index(['event_id', 'year', 'month', 'day', 'country_code', 'country_name',
#        'region_code', 'region_name', 'state', 'city', 'latitude', 'longitude',
#        'success', 'suicide', 'attacktype_code', 'attacktype_name',
#        'targettype_code', 'targettype_name', 'corporation', 'target',
#        'nationality', 'nationality_name', 'group_name', 'motive', 'individual',
#        'weaptype_code', 'weapontype_name', 'claimed', 'weapon_details',
#        'fatalities', 'injured', 'property_damage', 'propganda_value',
#        'ransom_demand', 'addnotes', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'summary', 'total_casualties'],
#       dtype='object')

# %% [markdown]
# ###Destructive Feature of data.

# %%
## Total kills and injured
print(f"Total Fatalities recorded according to the dataset is:- {terror['fatalities'].sum()}")

## total injured in the attacks
print(f"Total Injured recorded according to the dataset is:- {terror['injured'].sum()} ")

## Total affected people
print(f"Total affected peopls in the attacks is:- {terror['fatalities'].sum() + terror['injured'].sum()}")
# Out:
# Total Fatalities recorded according to the dataset is:- 317911
# Total Injured recorded according to the dataset is:- 499102
# Total affected peopls in the attacks is:- 817013

# %%
most_df = pd.DataFrame({'Entry':['Country with the most attacks','City with the most attacks','Region with the most attack',
                                 'Year With the Most Attack','Month With the Most Attack','Group With Most Attack','Most Types Of attack',
                                 'Target With most Attack'],
                        'values':[terror['country_name'].value_counts().idxmax(),terror['city'].value_counts().idxmax(),
                        terror['region_name'].value_counts().idxmax(),terror['year'].value_counts().idxmax(),
                                  terror['month'].value_counts().idxmax(),terror['group_name'].value_counts().index[1],
                                  terror['attacktype_name'].value_counts().idxmax(),terror['targettype_name'].value_counts().idxmax()]})

# %%
table = tabulate(most_df,tablefmt='fancy_grid')
print(table)
# Out:
# ╒═══╤═══════════════════════════════╤═════════════════════════════╕
# │ 0 │ Country with the most attacks │ Iraq                        │
# ├───┼───────────────────────────────┼─────────────────────────────┤
# │ 1 │ City with the most attacks    │ Baghdad                     │
# ├───┼───────────────────────────────┼─────────────────────────────┤
# │ 2 │ Region with the most attack   │ Middle East & North Africa  │
# ├───┼───────────────────────────────┼─────────────────────────────┤
# │ 3 │ Year With the Most Attack     │ 2014                        │
# ├───┼───────────────────────────────┼─────────────────────────────┤
# │ 4 │ Month With the Most Attack    │ 5                           │
# ├───┼───────────────────────────────┼─────────────────────────────┤
# │ 5 │ Group With Most Attack        │ Taliban                     │
# ├───┼───────────────────────────────┼─────────────────────────────┤
# │ 6 │ Most Types Of attack          │ Bombing/Explosion           │
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ####**Manipulations**
#
# 1.Identifying and handling missing values using methods like dropna or fillna.
#
# 2.Replace the missing values which the desired values in the columns
#
# 3.Drop some rows from the dataset which are consisting the NULL values
#
# 4.Remove the duplicates from the dataset
#
# **After doing all the data wrangling task Now We have the Neat and clean dataset for analysis**
#
# ####**Insights**
#
# 1.Total Fatalities recorded according to the dataset is:- 317911
#
# 2.Total Injured recorded according to the dataset is:- 499102
#
# 3.Total affected peopls in the attacks is:- 817013
#
# 4.Country with the most attacks: Iraq
#
# 5.City with the most attacks: Baghdad
#
# 6.Region with the most attacks: Middle East & North Africa
#
# 7.Year with the most attacks: 2014
#
# 8.Month with the most attacks: 5
#
# 9.Group with the most attacks: Taliban
#
# 10.Most Attack Types: Bombing/Explosion

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ####**Line Plot to show the trends of the terrorist activity over time and pattern in the frequncy of the terror attacks.**

# %%
# Chart - 0 visualization code
# We draw a line Plot to show the trends of the terrorist activity over time and pattern in the frequncy of the terror attacks
# Set The Plot Style
sns.set_style("darkgrid")

# Prepare The Data
x = terror['year'].unique()
y = terror['year'].value_counts().sort_index(ascending=True)

# Preapare The Figure
plt.figure(figsize = (18,8))

# Plot The Chart
plt.plot(x,y)

# Customize The Plot
plt.xlabel('Years')
plt.ylabel('Terrorist Activities')
plt.title("Line Plot For Showing the Trends in the terrorist activity over time")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line Chart is very usefull to show the trend over the time, So thats why i pick up line chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some usefull insights from the line chart of Attacks over time is:-
#
# A).Attacks frequncy in attacks is varries over time, Sometimes its high and sometime its low.
#
# B).On a genral note Attacks number's increase rapidly since 1970.
#
# C).In 1970-1980 its slightly low compair to 2010 - 2017.
#
# D).It is at peak in 2010-2017.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impacts:-**
#
# Improved Security Measures:Positive Impact:- Understanding the trends can lead to more effective security measures, reducing the risk of harm to employees, customers, and assets.
#
# Better Resource Allocation:- Organizations can allocate resources more efficiently, focusing on areas or periods with higher risk, which contributes to cost savings and risk mitigation
#
# **Negative Business Impacts:-**
#
# Increased Security Costs:If the analysis reveals a rising trend in terrorist activity, businesses may need to increase spending on security measures, potentially impacting overall operational costs

# %% [markdown]
# ####**Bar Plot Of Total Attacks Over The Time**

# %%
# Chart - 1 visualization code
# Bar - Plot for the attacks per year
# Set The Plot Style
sns.set_style("darkgrid")

# Preapare The Data
x_year = terror['year'].unique()
y_year = terror['year'].value_counts().sort_index()

# Preapare The Figure
plt.figure(figsize = (18,8))

# Select A Colormap
colormap = plt.cm.Reds
normalize = plt.Normalize(min(y_year),max(y_year))

# Plot The Chart
sns.barplot(data = terror,x = x_year,y = y_year,palette=colormap(normalize(y_year)))

# Customize The Plot
plt.xticks(rotation = 45)
plt.xlabel("Year Of Attack")
plt.ylabel("Number Of Attack")
plt.title("Bar Plot For Number of Terrorist Activities Per Year")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are effective for comparing the magnitude of different categories or groups. In the context of a terrorism dataset, each bar represents a specific year, and the height of the bar corresponds to the total number of attacks in that year. This makes it easy to compare the number of attacks across different years at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some insights which we can see btw number of attacks and year is :-**
#
# A).Bar Chart shows that the number of attack since 1970 increase slightly over the time.
#
# B).From 1970 to 1992 attacks increase then some decreament to be shown till 2004.
#
# C).After that the number of attacks increase rapidly.
#
# D).Most Number of attacks recorded in the 2014.
#
# E).Attacks has higher frequency in years 2012 to 2017 and its very concerning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impacts:-**
#
# Strategic Decision-Making:- Trends in total attacks can inform strategic decisions, guiding businesses in choosing locations for expansion or reconsidering operations in regions with heightened security risks.
#
# Improved Risk Management:- Understanding the historical trends allows businesses to develop more robust risk management strategies, reducing the likelihood of disruptions to operations and supply chains.
#
# Community Engagement:-Businesses can use insights from the bar plot to engage with local communities and collaborate on initiatives that enhance security and contribute to a safer environment
#
# **Negative Bussiness Impacts:-**
#
# Market Volatility:- Regions experiencing an increase in attacks may face market volatility, affecting investor confidence and potentially impacting businesses operating in those areas.
#
# Supply Chain Disruptions:- High-frequency attacks may lead to disruptions in the supply chain, impacting the flow of goods and services and potentially affecting business continuity.
#
# Reputational Damage:- Persistent security concerns, as indicated by a high number of attacks, can lead to reputational damage, affecting customer trust and loyalty

# %% [markdown]
# ####**Pie Chart Of Most Affected Regions**

# %%
# Chart - 2 visualization code
# Most Affected Regions
# We use Piechart to show most affected Regions due to terrorism
# Preapare The Data
regions = np.sort(terror['region_name'].unique())
counts_of_attack = terror['region_name'].value_counts().sort_index()

# Preapare The Figure
plt.figure(figsize = (15,10))

# Plot The Chart
plt.pie(counts_of_attack,labels = regions,autopct='%0.1f%%')

# Customize The Plot
plt.title('Pie Chart of The Affected Region')
plt.axis('equal')

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing a pie chart to represent the distribution of terrorist attacks across regions can be a suitable choice for specific scenarios.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **There are some usedfull insights found in this pie chart:-**
#
# A).Terrorist attacks happened almost in every Region.
#
# B).South Asia, Middle East and North Africa, South America followed by the Western Europe are the most affected regions in the world.
#
# C).Least attacks happened in Australasia & occiana, East Asia followed by the Central Asia.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# No

# %% [markdown]
# ####**Bar Plot Of Most Affected Countries**

# %%
# Chart - 3 visualization code
# Bar Chart of most affected countries
# We Have a Large number of the countries so we just pick top 50 countries for visualize
# Preapare The Data
top_country_df = terror.groupby('country_name')['event_id'].count().sort_values(ascending=False).reset_index().head(50)
top_country_df.rename(columns = {'event_id':"no_of_attacks"},inplace = True)

# Preapare The Figure
plt.figure(figsize = (18,10))

# Plot The Chart
sns.barplot(data = top_country_df,y ='country_name',x ='no_of_attacks')

# Customize The Plot
plt.xlabel("Number Of Attacks")
plt.ylabel('Country Names')
plt.title('Top 50 Country Affected By Terrorism')

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing a bar chart for visualizing data on countries and total attacks in a terrorism dataset can be a good option for several reasons:
#
# **A).Comparison:-** Bar charts make it easy to compare the number of attacks across different countries. The lengths of the bars provide a visual representation of the magnitude of each country's total attacks, allowing for quick comparisons.
#
# **B).Categorical Data:-** Bar charts are particularly effective for displaying categorical data, such as countries. Each bar represents a distinct category (country), making it straightforward for viewers to interpret the information.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **This is the bar chart of top 50 affected countries There are some useful in sights founds in the bar**
#
# A).Country with the most number of attack is IRAQ.
#
# B).Pakistan and India is most affected country after Iraq.
#
# C).Afganistan, Colambia, Philipins, Peru, United kingdom Are also have large number of terrorist attacks in the world.
#
# D).West Germany, Myanmar, Angola, Japan , Uganda are some countries in top 50 which also have very less number of attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Area Plot Of Most Affected Regions Over The Time**

# %%
# Chart - 4 visualization code
# Area Chart for the Affected Regions Over The Years
# Preapare The Data
crosstable = pd.crosstab(terror.year,terror.region_name)

# Plot The Chart
crosstable.plot(kind = 'area',figsize=(18,7))

# Customize The Chart
plt.xlabel("Years")
plt.ylabel("Number Of Attacks")
plt.title("Affected Regions Over The Years")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing an area plot for visualizing the most affected regions over time in a terrorism dataset can offer several advantages.
#
# A).Trend Visualization
#
# B).Comparison of Multiple Regions
#
# C).Highlighting Magnitude
#
# D).Identification of Patterns and Shifts

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some are very usefull insights founds in the area chart over the time.**
#
# A).In 1970's most affeted region is North America.
#
# B).In 1980's most affeted region is Western Europe And Central America & Caribabian.
#
# C).In 1990's most affeted region is South America.
#
# D).In 2000's most affeted region is South Asia and Middle East & North Africa
#
# E).In 2010's most affeted region is Middle East & North Africa

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Folium Map To Show Top 200 Hotspots Cities All Over The World**

# %%
# Chart - 5 visualization code
# Top Hotspots On The Map By City
# Top 200 Cities Hotspots
top_cities = terror.groupby(['city','latitude','longitude'])['event_id'].count().sort_values(ascending=False).head(200).reset_index()

# Create a Folium map centered at an average

map_center = [top_cities['latitude'].mean(), top_cities['longitude'].mean()]
my_map = folium.Map(location=map_center, zoom_start=4)

# Add markers for each city
for index, row in top_cities.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"{row['city']}"
    ).add_to(my_map)
# Display the Map
display(my_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Folium is handy for exploring geographical datasets. You can visualize the distribution of data points, such as locations of events, places of interest, or any other spatially relevant information.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Folium Map helps us to find spatial distribution of terrorist incidents,Some usefull in sights from folium map**
#
# A).Maps shows the top 200 cities in which frequency of attack is hight.
#
# B).Folium Map shows top hotspots area of diffrent cities.It's help to visualize Top hotspot for quick learnings.
#
# C).Folium Map show top hotspots in variuos continents all over the world.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Line Chart To Show The Trend Of Casulaties Over Time**

# %%
# Chart - 6 visualization code
# Total People affected over the Time
# Preapare The Data
affected = terror.groupby(['year'])['total_casualties'].sum().reset_index()

# Bar plot for total casualties
plt.figure(figsize = (18,8))

# Plot the Bar
sns.lineplot(data = affected,x = 'year',y = 'total_casualties',palette = "Blues")

# Cutomize The Plot
plt.xticks(rotation = 90)
plt.xlabel("Years")
plt.ylabel("Total Casualties")
plt.title("Total Affected People Over The Time")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line Chart is very usefull to show the trend over the time, So thats why i pick up line chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some usefull insights from the line chart of Casulties over time is:-**
#
# A).Casulties frequncy in attacks is varries over time, Sometimes its high and sometime its low.
#
# B).On a genral note Casulties  number's increase rapidly since 1970.
#
# C).In 1970-1980 its slightly low compair to 2010 - 2017.
#
# D).It is at peak in 2010-2017.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Bar Chart For Total People Killed In Top 50 Countries**

# %%
# Chart - 7 visualization code
# Total People Killed In The Terrorist Attack Of The Countries (TOP 50)
plt.figure(figsize = (18,8))

# Preapare The Data
# Filtering Total Killed Peoples
total_kill = terror.groupby('country_name')['fatalities'].sum().sort_values(ascending=False).reset_index().head(50)

# Plot The Chart
sns.barplot(data = total_kill,x = 'country_name',y='fatalities',palette='viridis')

# Customize The Plot
plt.xticks(rotation = 90)
plt.xlabel('Countries')
plt.ylabel("Killed Peoples In The Attacks")
plt.title("Total People Killed By Countries")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing a bar chart to visualize the total number of people killed in different cities has several advantages:-
#
# A).Clear Comparison
#
# B).Categorical Data Representation
#
# C).Hierarchical Display

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some Useful insights in bar chart of killed people in diffrent countries:-**
#
# A).Most people killed in IRAQ  followed by Afganistan, Pakistan, India.
#
# B).Srilanka, Nigiria, Peru and Some other countries also have a healthy numbers in attaks killig.
#
# C).Indonesia, Myanmar, China, Chad luckily have least number of killed people in terror attacks in top 50 countries

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Horizontal Bar Chart For Most Used Attack Types**

# %%
# Chart - 8 visualization code
# Total Number Of Attacks By Diffrent Attack Types
# Prepare The Data
attack_type = terror['attacktype_name'].unique()
attack_count = terror.groupby('attacktype_name')['event_id'].count()

# Preapare The Axis
plt.figure(figsize = (18,8))

# Plot The Chart
sns.barplot(data = terror,x = attack_count,y = attack_type,palette='viridis')

# Customize The Plot
plt.xlabel("Number Of Attacks")
plt.ylabel("Attack Types")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing a bar chart to visualize the total number of people killed in different cities has several advantages:-
#
# A).Clear Comparison
#
# B).Categorical Data Representation
#
# C).Hierarchical Display

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **These are some insights which i found in bar chart:-**
#
# A).Bar chart shows that most used attack type throught Bombing/Explosion.
#
# B).Lots of attacks were also made throught attack type Armed Assult and Assassination.
#
# C).Few Attack Types also are Hostage taking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Pie Chart For Most Targeted Sectors**

# %%
# Chart - 9 visualization code
# Top 50 Most Targeted Sectors
# Preapare The Data
sectors = terror['targettype_name'].unique()
attacks = terror.groupby('targettype_name')['targettype_code'].count()

# Preapare The Axis
plt.figure(figsize = (18,12))

# Plot The Chart
plt.pie(attacks,labels = sectors)

# Customize The Plot
plt.xticks(rotation = 90)
plt.title("Attack On The Diffrent Sectors")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing a pie chart to represent the distribution of terrorist attacks across regions can be a suitable choice for specific scenarios.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some important insights found in this pie chart is given below:-**
#
# A).Major Target Type for the terrorist is Telecommunication.
#
# B).Education Insitutes, NGO's, Miltery Bases, Private Citizen Property also among the top sectors for terrorists.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Bar Chart For Top 50 Most Targeted Corporation**

# %%
# Chart - 10 visualization code
# Top 40 Corporation With Most Numbers Of Attack
# Preapare The Data
corp = terror['corporation'].value_counts().head(40).reset_index().iloc[1:]
corp.rename(columns = {'index':'corporation','corporation':'attacks'},inplace = True)

# Preapare The Figure
plt.figure(figsize = (18,12))

# Plot The Chart
sns.barplot(data = corp,x = 'attacks',y = 'corporation',palette = 'viridis')

# Customize The Plot
plt.xlabel("Number Of Attacks")
plt.ylabel("Corporations")
plt.title("Top 40 Most Attacked Corporation")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing a bar chart to visualize the total number of people killed in different cities has several advantages:-
#
# A).Clear Comparison
#
# B).Categorical Data Representation
#
# C).Hierarchical Display

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **These are some usefull insights from the bar chart of most targeted Corporation**
#
# A).Iraqi Police Service(IPS) Were top targeted corporation in the world.
#
# B).Goverments, Police, Militery, Civilions are among the top targeted corporation.
#
# C).Armed Police Of Pillipinse(APOP) is least targeted corporation in Top 50 corporation

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Area Chart For The Weapon Type Used Over The Time**

# %%
# Chart - 11 visualization code
# Most of Weapons Used Over Time In The Terrorist Attacks
# Preapare The Data
tab = pd.crosstab(terror.year,terror.weapontype_name)

# Plot The Chart
tab.plot(kind = 'area',figsize = (20,10))

# Customize The Plot
plt.xlabel("Years")
plt.ylabel("Total Number Of Attacks")
plt.title("Weapon Types Used Over The Time")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing an area plot for visualizing the most affected regions over time in a terrorism dataset can offer several advantages.
#
# A).Trend Visualization
#
# B).Comparison of Multiple Regions
#
# C).Highlighting Magnitude
#
# D).Identification of Patterns and Shifts

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some very useful insights from the area chart is :-**
#
# A).Overall most used Weapon Type is Explosive.
#
# B).Firearms is second most used Weapon Type over the time.
#
# C).Bilogical Weapon Type is least used over the time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Bar Plot For Top 20 Weapons Detais**

# %%
# Chart - 12 visualization code
# Top 20 Weapons Used in The Attacks
# Preapare The Data
weapon_details = terror['weapon_details'].value_counts().reset_index().head(20)
weapon_details.rename(columns = {'index':'Weapon','weapon_details':'Details'},inplace = True)

# Prepare The Figure
plt.figure(figsize = (18,8))

# Plot the chart
sns.barplot(data = weapon_details,x = 'Details',y = 'Weapon',palette = 'viridis')

# Customize The Plot
plt.xlabel('Number Of Attacks')
plt.ylabel('Weapon Details')
plt.title('Top 20 Weapons Used In The Attacks')

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing a bar chart to visualize the total number of people killed in different cities has several advantages:-
#
# A).Clear Comparison
#
# B).Categorical Data Representation
#
# C).Hierarchical Display

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Usefull insights founds in this bar plot:-**
#
# A).Most attacks were made with use of Explosive.
#
# B).Automatics Firearms,Pistol were used to attack.
#
# C).Greandes ,Knife and Firearms also used most in  attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Bar Plot For Most Active Terrorist Groups Over The Time**

# %%
# Chart - 13 visualization code
# Top 50 Most Active Groups Throght The Years
groups = terror['group_name'].value_counts().reset_index().head(51)

# We know There are most attacks which is not knows so we ignore the unknows groups
top_50_groups = groups.iloc[1:]
top_50_groups.rename(columns = {'index':'group_name','group_name':'attacks'},inplace = True)

# Preapare The Figure
plt.figure(figsize = (18,8))

# Plot The Chart
sns.barplot(data = top_50_groups,x = 'group_name',y = 'attacks')


# Customize The Plot
plt.xticks(rotation = 90)
plt.xlabel("Groups Names")
plt.ylabel("Number Of Attacks")
plt.title("Most 20 Active Groups")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Choosing a bar chart to visualize the total number of people killed in different cities has several advantages:-
#
# A).Clear Comparison
#
# B).Categorical Data Representation
#
# C).Hierarchical Display

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some Usefull insights from the bar chart of top active groups over the time:-**
#
# A).Taliban is most active group from 1970 to 2017.
#
# B).Islamic State Of Iraq and The leavent (ISIL) is second most active group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ####**Bar Plot To Show That In How Many Attacks Suicide Happened**

# %%
# Visualization Code
# Is there Suicide happend or not in the attack
# Preapare The Data
suicide = terror['suicide'].value_counts().reset_index()

# Preapare The Figure
plt.figure(figsize = (12,6))

# Plot The Chart
sns.barplot(data = suicide,x = 'index',y ='suicide')

# Customize The Plot
plt.xlabel("Suicide Happened Or Not")
plt.ylabel("Number Of Atacks")
plt.title('Suicide Happend Or Not Chart')

# Show The Plot
plt.show()

# %% [markdown]
# ####**Bar Plot For Showing How Many Attacks Damaged The Property**

# %%
# Visualization Code
# Propery Damage Or Not
# Preapare The Data
property_damage = terror['property_damage'].value_counts().reset_index()

# Preapare The Figure
plt.figure(figsize = (12,6))

# Plot The Chart
sns.barplot(data = property_damage,x = 'index',y = 'property_damage')

# Customize The Plot
plt.xlabel('Property Damage Or Not')
plt.ylabel('Number Of Attacks')
plt.title('Bar Plot For Property Damage')

# Show The plot
plt.show()

# %% [markdown]
# ####**Pie Chart To Show Any International Ideology behind With The Attack.**

# %%
# Visualization Code
# Any International Connection Or Not
# Preapare The Data
international_ideology = terror['INT_IDEO'].value_counts().reset_index()

# Preapare The Figure
plt.figure(figsize = (12,8))

# Plot The Chart
plt.pie(international_ideology['INT_IDEO'],labels = international_ideology['index'],autopct='%1.1f%%',startangle=140)

# Customize The Plot
plt.title('Internation Ideology Behind The Attack')

# Show The Plot
plt.show()

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Prapare The Data
correaltion_matrix = terror.corr()

# Preapare The Figure
plt.figure(figsize = (18,8))

# Plot The Heatmap
sns.heatmap(data = correaltion_matrix,annot = True,cmap='coolwarm')

# Customize The Plot
plt.title("Correlation Heatmap Of Total Casualties, Total Death And Total Injured")

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap in a terrorism dataset can provide insights into the relationships between different variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  **Here are some useful insights you might gain from examining a correlation heatmap:-**
#
#  A).

# %% [markdown]
# ####**Pair Plot For Total casualities , fatalities , injured with the regions**

# %%
# Pair Plot visualization code
# Pair Plot For Some Columns From Our Dataset Which Are Correlated To each Other
# Preapare The Data
pair_data = terror[['total_casualties','fatalities','injured','region_name']]

# Because Pair Plot Take To Much Time For Execution So we Select 1000 Randome rows
random_sample = pair_data.sample(n = 10000)

# Preapare The Figure
plt.figure(figsize = (18,8))

# Plot The Chart
sns.pairplot(random_sample,hue = 'region_name')

# Show The Plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot, also known as a scatterplot matrix, is a useful visualization for exploring relationships between multiple variables in a dataset. However, the utility of a pair plot in a terrorism dataset depends on the specific variables available

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Some usefull insights from the pair plot is :-**
#
# A).Univariate Distributions:- We can see that there is a kernal density curve its define the distribution of the variable by itself.
#
# B).Bivariate Relationships:- Scatterplots in the upper and lower triangles of the pair plot show the relationships between pairs of variables. You can identify trends, patterns, and potential correlations between variables.
#
# C).Identifying Outliers:- Outliers may stand out in the scatterplots.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Analyzing a terrorism dataset can serve several business objectives, depending on the goals and context of the analysis. Here are some common business objectives for conducting an analysis on a terrorism dataset:
#
# 1. **Risk Assessment and Mitigation:**
#    - **Objective:** Identify regions or areas with a higher risk of terrorist activities and develop strategies to mitigate these risks.
#    - **Business Impact:** Enhanced security measures, improved risk management, and proactive planning to safeguard assets, personnel, and operations.
#
# 2. **Resource Allocation Optimization:**
#    - **Objective:** Optimize the allocation of resources, including budget, personnel, and technology, to areas or periods with higher security risks.
#    - **Business Impact:** Cost savings, more effective use of resources, and improved overall security preparedness.
#
# 3. **Strategic Decision-Making:**
#    - **Objective:** Inform strategic decisions regarding market entry, expansion, or withdrawal based on the security landscape.
#    - **Business Impact:** Improved strategic planning, reduced exposure to security risks, and better alignment with long-term business goals.
#
# 4. **Supply Chain Resilience:**
#    - **Objective:** Enhance the resilience of the supply chain by identifying and mitigating security risks that may impact the flow of goods and services.
#    - **Business Impact:** Reduced supply chain disruptions, improved operational continuity, and increased customer satisfaction.
#
# 5. **Market Presence and Reputation Management:**
#    - **Objective:** Manage and safeguard the business's market presence and reputation in regions affected by terrorism.
#    - **Business Impact:** Minimized reputational damage, increased customer trust, and the ability to maintain a positive market image.
#
# 6. **Humanitarian Aid Planning:**
#    - **Objective:** Plan and allocate resources for humanitarian aid in regions affected by terrorism.
#    - **Business Impact:** Positive contribution to affected communities, strengthened corporate social responsibility, and improved community relations.
#
# 7. **Investor Confidence and Stakeholder Communication:**
#    - **Objective:** Maintain or enhance investor confidence by effectively communicating security measures and risk management strategies.
#    - **Business Impact:** Positive relationships with stakeholders, sustained or improved stock prices, and continued investment support.
#
# 8. **Regulatory Compliance:**
#    - **Objective:** Ensure compliance with regional and international security regulations and requirements.
#    - **Business Impact:** Avoidance of legal and regulatory issues, reduced risk of fines or sanctions, and smoother business operations.
#
# 9. **Employee Safety and Well-being:**
#    - **Objective:** Ensure the safety and well-being of employees by implementing measures to protect them in regions with security risks.
#    - **Business Impact:** Improved employee morale, increased productivity, and reduced turnover.
#
# 10. **Community Engagement:**
#     - **Objective:** Engage with local communities in regions affected by terrorism to build positive relationships and contribute to security initiatives.
#     - **Business Impact:** Positive community relations, enhanced corporate social responsibility, and potential business opportunities.
#
# These objectives highlight the importance of using terrorism data analysis to inform decision-making, enhance security measures, and contribute to the overall resilience and success of the business in regions with security challenges.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Results of Analysis**
#
# - Most of the attacks were attacked through explosives and then through firearms.
#
# - Attacks were more during 2014 and then in 2015. When compared to
#   attacks from 1970 onwards, the last 6 years scored a maximum. But from
#   2014 onwards count started decreasing.
#
# - Iraq dominates all the countries and it has the highest number of attacks and then Pakistan, Afghanistan, and India follow it.
# - The Middle East& North Africa leads 1st among all the regions and then South Asia takes 2nd place.
# - For most of the attacks, the target is Private Citizens& property and the next Military leads.
# Most of the attacks were through either Bombing or Explosion.

# %% [markdown]
# **Measures to be Taken to Reduce Terrorism**
#
# - By reducing access to dangerous weapons
#
# - Government should provide more security over countries
#
# - Security should be strengthened across borders
# - Government should take measures on increased immigration
# and many more…
